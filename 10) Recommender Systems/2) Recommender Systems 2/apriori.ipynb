# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("Online_Retail (1).csv")
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#      InvoiceDate  UnitPrice  CustomerID         Country
# 0  01/12/10 8:26       2.55     17850.0  United Kingdom
# 1  01/12/10 8:26       3.39     17850.0  United Kingdom
# 2  01/12/10 8:26       2.75     17850.0  United Kingdom
# 3  01/12/10 8:26       3.39     17850.0  United Kingdom
# 4  01/12/10 8:26       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
print('Number of Unique Invoice numbers: {cnt}'.format(cnt=df.InvoiceNo.nunique()))
print('Number of Unique Customer IDs: {cnt}'.format(cnt=df.CustomerID.nunique()))
# Out:
# Number of Unique Invoice numbers: 25900
# Number of Unique Customer IDs: 4372

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df = df[df['Quantity']>=0]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 531285 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    531285 non-null  object
#  1   StockCode    531285 non-null  object
#  2   Description  530693 non-null  object
#  3   Quantity     531285 non-null  int64
#  4   InvoiceDate  531285 non-null  object
#  5   UnitPrice    531285 non-null  float64
#  6   CustomerID   397924 non-null  float64
#  7   Country      531285 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 36.5+ MB

# %%
df.dropna(axis=0, subset=['InvoiceNo'],inplace=True)
df['InvoiceNo']=df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]
df.shape
# Out:
# (531285, 8)

# %%
df['Country'].value_counts()
# Out:
# United Kingdom          486286
# Germany                   9042
# France                    8408
# EIRE                      7894
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1967
# Portugal                  1501
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Unspecified                446
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     295
# Hong Kong                  284
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# European Community          60
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              25
# Bahrain                     18
# Saudi Arabia                 9
# Name: Country, dtype: int64

# %%
data = (df[df['Country'] =="United Kingdom"].groupby(['InvoiceNo', 'Description'])['Quantity']
               .sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))
data.head(2)
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                  0.0                             0.0
# 536366                                  0.0                             0.0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                      0.0                           0.0
# 536366                      0.0                           0.0
#
# Description   NINE DRAWER OFFICE TIDY   OVAL WALL MIRROR DIAMANTE   \
# InvoiceNo
# 536365                            0.0                          0.0
# 536366                            0.0                          0.0
#
# Description   RED SPOT GIFT BAG LARGE   SET 2 TEA TOWELS I LOVE LONDON   \
# InvoiceNo
# 536365                            0.0                               0.0
# 536366                            0.0                               0.0
#
# Description   SPACEBOY BABY GIFT SET   TOADSTOOL BEDSIDE LIGHT   ...  \
# InvoiceNo                                                        ...
# 536365                           0.0                        0.0  ...
# 536366                           0.0                        0.0  ...
#
# Description  returned  taig adjust  test  to push order througha s stock was   \
# InvoiceNo
# 536365            0.0          0.0   0.0                                  0.0
# 536366            0.0          0.0   0.0                                  0.0
#
# Description  website fixed  wrongly coded 20713  wrongly coded 23343  \
# InvoiceNo
# 536365                 0.0                  0.0                  0.0
# 536366                 0.0                  0.0                  0.0
#
# Description  wrongly marked  wrongly marked 23343  \
# InvoiceNo
# 536365                  0.0                   0.0
# 536366                  0.0                   0.0
#
# Description  wrongly sold (22719) barcode
# InvoiceNo
# 536365                                0.0
# 536366                                0.0
#
# [2 rows x 4058 columns]

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
    
data = data.applymap(encode_units)
data
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                    0                               0
# 536366                                    0                               0
# 536367                                    0                               0
# 536368                                    0                               0
# 536369                                    0                               0
# ...                                     ...                             ...
# 581585                                    0                               0
# 581586                                    0                               0
# A563185                                   0                               0
# A563186                                   0                               0
# A563187                                   0                               0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                        0                             0
# 536366                        0                             0
# 536367                        0                             0
# 536368                        0                             0
# 536369                        0                             0
# ...                         ...                           ...
# 581585                        0                             0
# 581586                        0                             0
# A563185                       0                             0
# A563186                       0                             0
# A563187                       0                             0
#
# Description   NINE DRAWER OFFICE TIDY   OVAL WALL MIRROR DIAMANTE   \
# InvoiceNo
# 536365                              0                            0
# 536366                              0                            0
# 536367                              0                            0
# 536368                              0                            0
# 536369                              0                            0
# ...                               ...                          ...
# 581585                              0                            0
# 581586                              0                            0
# A563185                             0                            0
# A563186                             0                            0
# A563187                             0                            0
#
# Description   RED SPOT GIFT BAG LARGE   SET 2 TEA TOWELS I LOVE LONDON   \
# InvoiceNo
# 536365                              0                                 0
# 536366                              0                                 0
# 536367                              0                                 0
# 536368                              0                                 0
# 536369                              0                                 0
# ...                               ...                               ...
# 581585                              0                                 0
# 581586                              0                                 0
# A563185                             0                                 0
# A563186                             0                                 0
# A563187                             0                                 0
#
# Description   SPACEBOY BABY GIFT SET   TOADSTOOL BEDSIDE LIGHT   ...  \
# InvoiceNo                                                        ...
# 536365                             0                          0  ...
# 536366                             0                          0  ...
# 536367                             0                          0  ...
# 536368                             0                          0  ...
# 536369                             0                          0  ...
# ...                              ...                        ...  ...
# 581585                             0                          0  ...
# 581586                             0                          0  ...
# A563185                            0                          0  ...
# A563186                            0                          0  ...
# A563187                            0                          0  ...
#
# Description  returned  taig adjust  test  to push order througha s stock was   \
# InvoiceNo
# 536365              0            0     0                                    0
# 536366              0            0     0                                    0
# 536367              0            0     0                                    0
# 536368              0            0     0                                    0
# 536369              0            0     0                                    0
# ...               ...          ...   ...                                  ...
# 581585              0            0     0                                    0
# 581586              0            0     0                                    0
# A563185             0            0     0                                    0
# A563186             0            0     0                                    0
# A563187             0            0     0                                    0
#
# Description  website fixed  wrongly coded 20713  wrongly coded 23343  \
# InvoiceNo
# 536365                   0                    0                    0
# 536366                   0                    0                    0
# 536367                   0                    0                    0
# 536368                   0                    0                    0
# 536369                   0                    0                    0
# ...                    ...                  ...                  ...
# 581585                   0                    0                    0
# 581586                   0                    0                    0
# A563185                  0                    0                    0
# A563186                  0                    0                    0
# A563187                  0                    0                    0
#
# Description  wrongly marked  wrongly marked 23343  \
# InvoiceNo
# 536365                    0                     0
# 536366                    0                     0
# 536367                    0                     0
# 536368                    0                     0
# 536369                    0                     0
# ...                     ...                   ...
# 581585                    0                     0
# 581586                    0                     0
# A563185                   0                     0
# A563186                   0                     0
# A563187                   0                     0
#
# Description  wrongly sold (22719) barcode
# InvoiceNo
# 536365                                  0
# 536366                                  0
# 536367                                  0
# 536368                                  0
# 536369                                  0
# ...                                   ...
# 581585                                  0
# 581586                                  0
# A563185                                 0
# A563186                                 0
# A563187                                 0
#
# [18194 rows x 4058 columns]

# %%
# data = data[(data > 0).sum(axis=1) >= 2]
# data

# %%
data.shape
# Out:
# (18194, 4058)

# %%
# !pip install mlxtend

# %%
from mlxtend.frequent_patterns import apriori

# %%
apriori(data, min_support=0.03, use_colnames=True)
# Out:
# C:\Users\kiit\avijit\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#       support                                           itemsets
# 0    0.046994                           (6 RIBBONS RUSTIC CHARM)
# 1    0.031934                  (60 CAKE CASES VINTAGE CHRISTMAS)
# 2    0.041387                      (60 TEATIME FAIRY CAKE CASES)
# 3    0.030505                   (72 SWEETHEART FAIRY CAKE CASES)
# 4    0.048148                       (ALARM CLOCK BAKELIKE GREEN)
# ..        ...                                                ...
# 135  0.036111  (JUMBO BAG RED RETROSPOT, JUMBO SHOPPER VINTAG...
# 136  0.038364  (JUMBO BAG RED RETROSPOT, JUMBO STORAGE BAG SUKI)
# 137  0.033363  (LUNCH BAG RED RETROSPOT, LUNCH BAG  BLACK SKU...
# 138  0.030450  (LUNCH BAG RED RETROSPOT, LUNCH BAG PINK POLKA...
# 139  0.030010  (PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...
#
# [140 rows x 2 columns]

# %%
frequent_itemsets_plus = apriori(data, min_support=0.03, 
                                 use_colnames=True).sort_values('support', ascending=False).reset_index(drop=True)

frequent_itemsets_plus['length'] = frequent_itemsets_plus['itemsets'].apply(lambda x: len(x))

frequent_itemsets_plus
# Out:
# C:\Users\kiit\avijit\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
frequent_itemsets_plus.loc[frequent_itemsets_plus.length==2]

# %%
from mlxtend.frequent_patterns import association_rules
rules = association_rules(frequent_itemsets_plus, metric ="lift", min_threshold = 1)
rules
