# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 6)

# %%
mobile_sales = pd.read_excel('mobilesales.xlsx')
mobile_sales.head()
# Out:
#         DATE   Sales
# 0 2001-01-01  6519.0
# 1 2001-02-01  6654.0
# 2 2001-03-01  7332.0
# 3 2001-04-01  7332.0
# 4 2001-05-01  8240.0

# %%
mobile_sales.dtypes
# Out:
# DATE     datetime64[ns]
# Sales           float64
# dtype: object

# %%
mobile_sales.Sales.describe()
# Out:
# count      198.000000
# mean     10842.757576
# std       2605.006293
# min        108.000000
# 25%       8856.000000
# 50%      10745.000000
# 75%      12399.750000
# max      23740.000000
# Name: Sales, dtype: float64

# %%
mobile_sales.DATE.describe()
# Out:
# /var/folders/pb/lctdnpp509v1l7y5t98dvxj00000gn/T/ipykernel_307/20359885.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   mobile_sales.DATE.describe()
# count                     217
# unique                    217
# top       2001-01-01 00:00:00
# freq                        1
# first     2001-01-01 00:00:00
# last      2019-01-01 00:00:00
# Name: DATE, dtype: object

# %%
mobile_sales.set_index('DATE', inplace=True)
mobile_sales
# Out:
#               Sales
# DATE
# 2001-01-01   6519.0
# 2001-02-01   6654.0
# 2001-03-01   7332.0
# 2001-04-01   7332.0
# 2001-05-01   8240.0
# ...             ...
# 2018-09-01  13838.0
# 2018-10-01  15351.0
# 2018-11-01  15615.0
# 2018-12-01  16941.0
# 2019-01-01  12160.0
#
# [217 rows x 1 columns]

# %% [markdown]
# ## Missing Values

# %%
mobile_sales.Sales.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
mobile_sales.isna().sum()
# Out:
# Sales    19
# dtype: int64

# %%
mobile_sales.loc[mobile_sales.Sales.isna()]
# Out:
#             Sales
# DATE
# 2002-03-01    NaN
# 2002-04-01    NaN
# 2002-05-01    NaN
# 2003-11-01    NaN
# 2005-10-01    NaN
# 2007-04-01    NaN
# 2009-03-01    NaN
# 2011-01-01    NaN
# 2011-06-01    NaN
# 2012-05-01    NaN
# 2013-02-01    NaN
# 2013-11-01    NaN
# 2014-08-01    NaN
# 2015-04-01    NaN
# 2015-09-01    NaN
# 2015-10-01    NaN
# 2016-07-01    NaN
# 2017-04-01    NaN
# 2017-08-01    NaN

# %% [markdown]
# #### No visible Patterns

# %% [markdown]
# #### Imputing with Mean/Median

# %%
mobile_sales.Sales.mean()
# Out:
# 10842.757575757576

# %%
mobile_sales.Sales.median()
# Out:
# 10745.0

# %%
mobile_sales.Sales.fillna(mobile_sales.Sales.mean()).plot(label='imputed')
mobile_sales.Sales.plot(label='original')
plt.legend()

# %% [markdown]
# #### As shown above, it is not appropriate to impute with mean

# %% [markdown]
# #### Filling '0' at missing values?

# %%
mobile_sales.Sales.fillna(0).plot(label='imputed')
mobile_sales.Sales.plot(label='original')
plt.legend()

# %% [markdown]
# ## Linear Interpolation

# %%
mobile_sales.Sales.interpolate(method='linear').plot(label='imputed')
mobile_sales.Sales.plot(label='original')
plt.legend()

# %%
# Let's save this interpolated signal 
mobile_sales.Sales = mobile_sales.Sales.interpolate(method='linear')

# %% [markdown]
# ## Detecting Anomalies

# %%
mobile_sales.Sales.hist(bins=100).plot()
# Out:
# []

# %%
mobile_sales.Sales.describe()
# Out:
# count      217.000000
# mean     10873.046083
# std       2571.620954
# min        108.000000
# 25%       8923.000000
# 50%      10793.000000
# 75%      12555.500000
# max      23740.000000
# Name: Sales, dtype: float64

# %%
mobile_sales.Sales.quantile(0.95)
# Out:
# 15164.599999999997

# %%
mobile_sales.Sales.quantile(0.05)
# Out:
# 7307.8

# %% [markdown]
# #### Clipping off anomalies (5-98 percentile)

# %%
mobile_sales.Sales.clip(upper=mobile_sales.Sales.quantile(0.95), lower=mobile_sales.Sales.quantile(0.05)).plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
mobile_sales.Sales.clip(upper=mobile_sales.Sales.quantile(0.98), lower=mobile_sales.Sales.quantile(0.02)).plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
mobile_sales.Sales = mobile_sales.Sales.clip(upper=mobile_sales.Sales.quantile(0.98), lower=mobile_sales.Sales.quantile(0.02))

# %% [markdown]
# ## Moving Averages

# %%
# Plot original data
mobile_sales.Sales.plot(label='original')

# Plot data after implementing Moving Averages
mobile_sales.Sales.rolling(3, center=False).mean().plot(label='smoothed')

plt.legend()

# %%
# Plot original data
mobile_sales.Sales.plot(label='original')

# Plot data after implementing Moving Averages
mobile_sales.Sales.rolling(1, center=False).mean().plot(label='smoothed')

plt.legend()

# %% [markdown]
# #### Taking higher window size

# %%
# Plot original data
mobile_sales.Sales.plot(label='original')

# Plot data after implementing Moving Averages
mobile_sales.Sales.rolling(12, center=False).mean().plot(label='smoothed')

plt.legend()

# %% [markdown]
# #### Centered MA

# %%
mobile_sales.Sales.plot(label='original')
mobile_sales.Sales.rolling(12, center=True).mean().plot(label='smoothed')
plt.legend()

# %%
# set center = False
mobile_sales.Sales.plot(label='original')
mobile_sales.Sales.rolling(12, center=False).mean().plot(label='smoothed')
plt.legend()

# %% [markdown]
# ## Trend

# %%
mobile_sales.Sales.plot(label='original')
mobile_sales.Sales.rolling(24, center=True).mean().plot(label='trend')

plt.legend()

# %% [markdown]
# ---

# %% [markdown]
# # Preprocessing

# %%
mobile_sales = pd.read_excel('mobilesales.xlsx')
mobile_sales.set_index('DATE', inplace=True)

# linear interpolation 
mobile_sales.Sales = mobile_sales.Sales.interpolate(method='linear')

# anomalies - clip quantiles
mobile_sales.Sales = mobile_sales.Sales.clip(upper=mobile_sales.Sales.quantile(0.98), lower=mobile_sales.Sales.quantile(0.02))

# plot
mobile_sales.Sales.plot(style='-o', figsize=(20,6))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# ## Decomposition

# %%
import statsmodels.api as sm

model = sm.tsa.seasonal_decompose(mobile_sales.Sales, model='additive')

# %%
model.plot();

# %%
model.seasonal[:12].plot(style='-o')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
model.resid.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
trend = mobile_sales.rolling(12, center=True).mean()
plt.plot(trend)
model.trend.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
de_trend = mobile_sales - trend
plt.plot(de_trend, '-o')

# %%
dtf = de_trend.reset_index()
dtf.groupby(dtf.DATE.dt.month)['Sales'].mean().plot(style='-o')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
dtf['season'] = dtf.groupby(dtf.DATE.dt.month)['Sales'].transform('mean')
dtf['season'].plot(style='-o')
# Out:
# <AxesSubplot:>

# %%
trend_2 = pd.Series((mobile_sales.values[:, 0] - dtf['season']).rolling(12, center=True).mean(), index=model.trend.index)
plt.plot(trend_2)
model.trend.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# ## Simple Forecasting Methods

# %%
train_max_date = mobile_sales.index[-12]
train_x = mobile_sales.loc[mobile_sales.index < mobile_sales.index[-12]].copy()
test_x = mobile_sales.loc[mobile_sales.index >= mobile_sales.index[-12]].copy()

test_x
# Out:
#               Sales
# DATE
# 2018-02-01  11852.0
# 2018-03-01  14123.0
# 2018-04-01  13360.0
# 2018-05-01  15576.0
# 2018-06-01  15809.4
# 2018-07-01  14080.0
# 2018-08-01  15697.0
# 2018-09-01  13838.0
# 2018-10-01  15351.0
# 2018-11-01  15615.0
# 2018-12-01  15809.4
# 2019-01-01  12160.0

# %%
from sklearn.metrics import (
    mean_squared_error as mse,
    mean_absolute_error as mae, 
    mean_absolute_percentage_error as mape
)

# Creating a function to print values of all these metrics.
def performance(actual, predicted):
    print('MAE :', round(mae(actual, predicted), 3))
    print('RMSE :', round(mse(actual, predicted)**0.5, 3)) 
    print('MAPE:', round(mape(actual, predicted), 3))

# %% [markdown]
# ### Mean

# %%
plt.rcParams['figure.figsize'] = (20,6)

# %%
test_x['pred'] = train_x['Sales'].mean()
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# MAE : 3786.031
# RMSE : 4025.906
# MAPE: 0.255

# %% [markdown]
# ### Naive (last value)

# %%
test_x['pred'] = train_x['Sales'][-1]

test_x.plot(style='-o')

performance(test_x['Sales'], test_x['pred'])
# Out:
# MAE : 3434.233
# RMSE : 3697.005
# MAPE: 0.23

# %% [markdown]
# ### Seasonal Naive

# %%
for i in test_x.index:
    test_x.loc[i]['pred'] = train_x.loc[i - pd.DateOffset(years=1)]['Sales']

test_x.plot(style='-o')

performance(test_x['Sales'], test_x['pred'])
# Out:
# MAE : 800.867
# RMSE : 1067.837
# MAPE: 0.055

# %% [markdown]
# ### Drift

# %%
# Get the slope
y_t = train_x['Sales'][-1]
m = (y_t - train_x['Sales'][0]) / len(train_x)
h = np.linspace(0,len(test_x)-1, len(test_x))

test_x['pred'] = y_t + m * h

test_x.plot(style='-o')

performance(test_x['Sales'], test_x['pred'])
# Out:
# MAE : 3321.482
# RMSE : 3586.323
# MAPE: 0.223

# %% [markdown]
# ## Train-Test Split

# %%
train_max_date = mobile_sales.index[-12]
train_x = mobile_sales.loc[mobile_sales.index < mobile_sales.index[-12]].copy()
test_x = mobile_sales.loc[mobile_sales.index >= mobile_sales.index[-12]].copy()

test_x
# Out:
#               Sales
# DATE
# 2018-02-01  11852.0
# 2018-03-01  14123.0
# 2018-04-01  13360.0
# 2018-05-01  15576.0
# 2018-06-01  15809.4
# 2018-07-01  14080.0
# 2018-08-01  15697.0
# 2018-09-01  13838.0
# 2018-10-01  15351.0
# 2018-11-01  15615.0
# 2018-12-01  15809.4
# 2019-01-01  12160.0

# %% [markdown]
# ## Performance Function

# %%
from sklearn.metrics import (
    mean_squared_error as mse,
    mean_absolute_error as mae, 
    mean_absolute_percentage_error as mape
)

# Creating a function to print values of all these metrics.
def performance(actual, predicted):
    print('MAE :', round(mae(actual, predicted), 3))
    print('RMSE :', round(mse(actual, predicted)**0.5, 3)) 
    print('MAPE:', round(mape(actual, predicted), 3))

# %% [markdown]
# ## Smoothing

# %% [markdown]
# #### Moving Average Forecasting

# %%
import numpy as np
df = mobile_sales.copy()

# %%
"""
    `start`: left bound for generating dates
    `periods`: Number of time steps in the range
    `freq`: frequency aliases
"""

pd.DataFrame(index = pd.date_range(start=df.index[-1], periods=12,freq='MS'))
# Out:
# Empty DataFrame
# Columns: []
# Index: [2019-01-01 00:00:00, 2019-02-01 00:00:00, 2019-03-01 00:00:00, 2019-04-01 00:00:00, 2019-05-01 00:00:00, 2019-06-01 00:00:00, 2019-07-01 00:00:00, 2019-08-01 00:00:00, 2019-09-01 00:00:00, 2019-10-01 00:00:00, 2019-11-01 00:00:00, 2019-12-01 00:00:00]

# %%
df = df.append(pd.DataFrame(index = pd.date_range(start=df.index[-1], periods=13,freq='MS')[1:]))
df.tail(20)
# Out:
# /var/folders/pb/lctdnpp509v1l7y5t98dvxj00000gn/T/ipykernel_307/2653082215.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(index = pd.date_range(start=df.index[-1], periods=13,freq='MS')[1:]))
#               Sales
# 2018-06-01  15809.4
# 2018-07-01  14080.0
# 2018-08-01  15697.0
# 2018-09-01  13838.0
# 2018-10-01  15351.0
# 2018-11-01  15615.0
# 2018-12-01  15809.4
# 2019-01-01  12160.0
# 2019-02-01      NaN
# 2019-03-01      NaN
# 2019-04-01      NaN
# 2019-05-01      NaN
# 2019-06-01      NaN
# 2019-07-01      NaN
# 2019-08-01      NaN
# 2019-09-01      NaN
# 2019-10-01      NaN
# 2019-11-01      NaN
# 2019-12-01      NaN
# 2020-01-01      NaN

# %%
df.Sales.tail(15)
# Out:
# 2018-11-01    15615.0
# 2018-12-01    15809.4
# 2019-01-01    12160.0
# 2019-02-01        NaN
# 2019-03-01        NaN
# 2019-04-01        NaN
# 2019-05-01        NaN
# 2019-06-01        NaN
# 2019-07-01        NaN
# 2019-08-01        NaN
# 2019-09-01        NaN
# 2019-10-01        NaN
# 2019-11-01        NaN
# 2019-12-01        NaN
# 2020-01-01        NaN
# Name: Sales, dtype: float64

# %% [markdown]
# #### Forecasting based on avg. of last three values

# %%
pred = df.Sales.dropna().values 

for i in range(12):
  pred = np.append(pred, pred[-3:].mean())

pred[-20:]
# Out:
# array([15809.4       , 14080.        , 15697.        , 13838.        ,
#        15351.        , 15615.        , 15809.4       , 12160.        ,
#        14528.13333333, 14165.84444444, 13617.99259259, 14103.99012346,
#        13962.6090535 , 13894.86392318, 13987.15436671, 13948.20911446,
#        13943.40913479, 13959.59087199, 13950.40304041, 13951.13434906])

# %%
pred = pred.round(1)
pred[-20:]
# Out:
# array([15809.4, 14080. , 15697. , 13838. , 15351. , 15615. , 15809.4,
#        12160. , 14528.1, 14165.8, 13618. , 14104. , 13962.6, 13894.9,
#        13987.2, 13948.2, 13943.4, 13959.6, 13950.4, 13951.1])

# %%
df['Pred'] = pred

df.loc[~df['Sales'].isna(), 'Pred'] = np.nan
df.tail(100).plot(style='-o')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Checking Performance

# %%
df = train_x.copy()

df = df.append(pd.DataFrame(index = pd.date_range(start=df.index[-1], periods=12,freq='MS')[1:]))

pred = df.Sales.dropna().values 

for i in range(12):
  pred = np.append(pred, pred[-3:].mean())

test_x['pred'] = pred[-12:]
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# /var/folders/pb/lctdnpp509v1l7y5t98dvxj00000gn/T/ipykernel_307/2361106519.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(index = pd.date_range(start=df.index[-1], periods=12,freq='MS')[1:]))
# MAE : 1692.467
# RMSE : 1875.03
# MAPE: 0.115

# %% [markdown]
# ## Simple Exponential Smoothing

# %%
model = pd.Series(sm.tsa.SimpleExpSmoothing(mobile_sales.Sales).fit(smoothing_level=1/(2*12)).fittedvalues)

model.plot(label='ses')
mobile_sales.Sales.plot(label='original')
plt.legend()
# Out:
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# #### Forecasting based on SES

# %%
model = sm.tsa.SimpleExpSmoothing(mobile_sales.Sales).fit(smoothing_level=1/(2*12))
pred = model.forecast(steps = 12)

mobile_sales.Sales.tail(100).plot(label='original', style='-o')

pred.plot(label='ses_pred', style='-o')
plt.legend()
# Out:
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# #### Performance - SES

# %%
model = sm.tsa.SimpleExpSmoothing(train_x.Sales).fit(smoothing_level=1/(2*12))
test_x['pred'] = model.forecast(steps = 12)
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# MAE : 1621.347
# RMSE : 1830.599
# MAPE: 0.109

# %% [markdown]
# ## Double Exponential Smoothing

# %%
model = sm.tsa.ExponentialSmoothing(mobile_sales.Sales, trend='add').fit(smoothing_level=0.4)
model.fittedvalues.plot(label='fitted')
mobile_sales.Sales.plot(label='original')
plt.legend()
# Out:
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %% [markdown]
# #### Forecasting - DES

# %%
pred = model.forecast(steps = 12)
mobile_sales.Sales.tail(100).plot(style='-o', label='actual')
pred.plot(style='-o', label='predicted')
plt.legend()

# %% [markdown]
# #### Performance - DES

# %%
model = sm.tsa.ExponentialSmoothing(train_x.Sales, trend='add').fit(smoothing_level=1/(2*12))
test_x['pred'] = model.forecast(steps = 12)
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# MAE : 1163.781
# RMSE : 1352.497
# MAPE: 0.083
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %% [markdown]
# ## Triple Exponential Smoothing

# %%
model = sm.tsa.ExponentialSmoothing(mobile_sales.Sales, trend='add', seasonal='add').fit(smoothing_level=0.4)
model.fittedvalues.plot()
mobile_sales.Sales.plot()
# Out:
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# #### Forecasting - TES

# %%
pred = model.forecast(steps = 12)
mobile_sales.Sales.tail(100).plot(style='-o')
pred.plot(style='-o')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# #### Performance - TES

# %%
model = sm.tsa.ExponentialSmoothing(train_x.Sales, trend='add', seasonal='add').fit(smoothing_level=1/(2*12))
test_x['pred'] = model.forecast(steps=12)
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# MAE : 584.39
# RMSE : 670.5
# MAPE: 0.04

# %% [markdown]
# #### Mixing additive and multiplicative models

# %%
model = sm.tsa.ExponentialSmoothing(train_x.Sales, trend='add', seasonal='mul').fit(smoothing_level=1/(2*12))
test_x['pred'] = model.forecast(steps=12)
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# MAE : 557.48
# RMSE : 614.448
# MAPE: 0.038

# %%
model = sm.tsa.ExponentialSmoothing(train_x.Sales, trend='mul', seasonal='add').fit(smoothing_level=1/(2*12))
test_x['pred'] = model.forecast(steps=12)
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# MAE : 150213778957.267
# RMSE : 152219770742.417
# MAPE: 10497726.985

# %% [markdown]
# # Stationarity

# %%
sm.tsa.stattools.adfuller(mobile_sales.Sales)[1]
# Out:
# 0.9789233920172064

# %%
def adf_test(dataset):
    pvalue = sm.tsa.stattools.adfuller(dataset)[1] 
    if pvalue <= 0.05:
      print('Sequence is stationary')
    else:
      print('Sequence is not stationary')

adf_test(mobile_sales.Sales)
# Out:
# Sequence is not stationary

# %%
mobile_sales.Sales.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
mobile_sales.Sales.diff().plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
mobile_sales.Sales.diff(1).diff(12).plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
sm.tsa.stattools.adfuller(mobile_sales.Sales.diff().dropna())[1]
# Out:
# 1.178188899632086e-16

# %%
sm.tsa.stattools.adfuller(mobile_sales.Sales.diff(1).diff(12).dropna())[1]
# Out:
# 1.4566207430682579e-06

# %% [markdown]
# ## ACF / PACF

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf 
plot_acf(mobile_sales.Sales);

# %%
plot_acf(mobile_sales.Sales.diff().dropna());

# %% [markdown]
# ## ARIMA

# %%
train_x.head()
# Out:
#               Sales
# DATE
# 2001-01-01  6802.44
# 2001-02-01  6802.44
# 2001-03-01  7332.00
# 2001-04-01  7332.00
# 2001-05-01  8240.00

# %%
train_x_st = train_x.copy()
train_x_st.Sales = train_x_st.Sales.diff(1)
train_x_st.dropna(inplace=True)
adf_test(train_x_st.Sales)
# Out:
# Sequence is stationary

# %%
import statsmodels as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model = SARIMAX(train_x_st.Sales, order=(1, 0, 0)) 
model = model.fit(disp=False)
test_x['pred'] = model.forecast(steps=12)
test_x['pred'].head(20)
# Out:
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# DATE
# 2018-02-01    1728.700559
# 2018-03-01    -635.966296
# 2018-04-01     233.963671
# 2018-05-01     -86.072171
# 2018-06-01      31.664824
# 2018-07-01     -11.649074
# 2018-08-01       4.285542
# 2018-09-01      -1.576595
# 2018-10-01       0.580009
# 2018-11-01      -0.213378
# 2018-12-01       0.078499
# 2019-01-01      -0.028879
# Name: pred, dtype: float64

# %%
test_x['pred'] = test_x['pred'].cumsum() + train_x.Sales[-1]

# %%
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# MAE : 2307.213
# RMSE : 2585.999
# MAPE: 0.153

# %%
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf

plot_acf(train_x_st.Sales);
plot_pacf(train_x_st.Sales);
# Out:
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
model = SARIMAX(train_x_st.Sales, order=(3, 0, 0)) 
model = model.fit(disp=False)
test_x['pred'] = model.forecast(steps=12)

# Integrating the trend back!
test_x['pred'] = test_x['pred'].cumsum() + train_x.Sales[-1]

# Plotting
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# MAE : 1647.061
# RMSE : 1890.003
# MAPE: 0.11
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model = SARIMAX(train_x_st.Sales, order=(0, 0, 1)) 
model = model.fit(disp=False)
test_x['pred'] = model.forecast(steps=12)

test_x['pred'] = test_x['pred'].cumsum() + train_x.Sales[-1]

test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# MAE : 1362.947
# RMSE : 1558.015
# MAPE: 0.093
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model = SARIMAX(train_x_st.Sales, order=(3, 0, 3)) 
model = model.fit(disp=False)
test_x['pred'] = model.forecast(steps=12)

test_x['pred'] = test_x['pred'].cumsum() + train_x.Sales[-1]

test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# MAE : 1298.654
# RMSE : 1521.157
# MAPE: 0.088

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model = SARIMAX(train_x.Sales, order=(3, 1, 3)) 
model = model.fit(disp=False)
test_x['pred'] = model.forecast(steps=12)
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# MAE : 1307.578
# RMSE : 1529.094
# MAPE: 0.088

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model = SARIMAX(train_x.Sales, order=(3, 1, 3)) 
model = model.fit(disp=False)
test_x['pred'] = model.forecast(steps=12)
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# MAE : 1307.578
# RMSE : 1529.094
# MAPE: 0.088

# %%
model = SARIMAX(train_x.Sales, order=(3, 1, 3), seasonal_order=(1,1,1,12)) 
model = model.fit(disp=False)
test_x['pred'] = model.forecast(steps=12)
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# MAE : 536.519
# RMSE : 622.166
# MAPE: 0.037
# /Users/gyanarora/miniconda3/envs/scaler/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
